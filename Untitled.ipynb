# %%
import pandas as pd
from scipy.io import arff
import matplotlib.pyplot as plt

def plot(pandaframe):
    pandaframe.hist(bins=50, figsize=(20,15))
    plt.show()
    
    
def analyzeBursts(pandaframe):
    new_df = pandaframe[pandaframe['class'] == b'1'].copy()
    df = pandaframe[pandaframe['class'] == b'0'].copy()
    new_df.hist(bins=50, figsize=(20,15))
    plt.show()
    df.hist(bins=50, figsize=(20,15))
    plt.show()
    new_df.corr()
    df.corr()
    

if __name__ == "__main__":

    arff_file = arff.loadarff('./data/seismic-bumpsdata.arff')

    pandaframe = pd.DataFrame(arff_file[0])

    #print(pandaframe.head())

    #print(pandaframe)

    #getBursts(pandaframe)
    #plot(pandaframe)
    analyzeBursts(pandaframe)
    

    
    
def getBursts(pandaframe):
    rockbursts = []
    count = 0

    for index, bclass in enumerate(pandaframe['class']):
        if bclass == b'1':
            rockbursts.append(index)
    for index in rockbursts:
        print(pandaframe.iloc[index])
        count = count + 1
    
    print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 33
#      29     #print(pandaframe)
#      30
#      31     #getBursts(pandaframe)
#      32     #plot(pandaframe)
# ---> 33     analyzeBursts(pandaframe)
#      34
#      35
#      36
#
# Cell In[7], line 17, in analyzeBursts(pandaframe)
#      13     new_df.hist(bins=50, figsize=(20,15))
#      14     plt.show()
#      15     df.hist(bins=50, figsize=(20,15))
#      16     plt.show()
# ---> 17     new_df.corr()
#      18     df.corr()
#
# File ~/code/Canary/.venv/lib/python3.13/site-packages/pandas/core/frame.py:13121, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13117         """  # noqa: E501
#   13118         data = self._get_numeric_data() if numeric_only else self
#   13119         cols = data.columns
#   13120         idx = cols.copy()
# ...
